# %%
import pandas as pd
exclusivity_df = pd.read_csv("exclusivity.txt", delimiter="~")
exclusivity_df.to_csv("exclusivity.csv", index=False)

# %%
patent_df = pd.read_csv("patent.txt", delimiter="~")
patent_df.to_csv("patent.csv", index=False)

# %%
products_df = pd.read_csv("products.txt", delimiter="~")
products_df.to_csv("products.csv", index=False)
